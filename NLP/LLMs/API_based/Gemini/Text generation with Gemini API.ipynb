# %% [markdown]
# # Text generation with Gemini API
#
# This notebook provides a comprehensive guide to using Google's Gemini API for text generation through the LangChain framework. We will explore various text generation techniques, from basic prompting to advanced use cases.

# %%
import os
from dotenv import load_dotenv
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.schema import HumanMessage, SystemMessage
from langchain.prompts import ChatPromptTemplate
import asyncio

# Load environment variables
load_dotenv()

# Set up API key
os.environ["GOOGLE_API_KEY"] = os.getenv('GOOGLE_API_KEY')

# %% [markdown]
# - `load_dotenv()`: Loads variables from a .env file into the environment
# - `os.getenv()`: Retrieves environment variables safely
# - We import `ChatGoogleGenerativeAI` as the main interface to Gemini models
# - `HumanMessage` and `SystemMessage` are LangChain's message types for structuring conversations
#
# ### Basic text generation
# Now that our setup is complete, let’s perform a simple text generation task using the Gemini 2.5 Flash model. This is the fastest Gemini model suitable for most lightweight NLP tasks.

# %%
# Initialize the Gemini model through LangChain's wrapper
llm = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0.7
)

# Send a basic prompt and receive a single response
response = llm.invoke("Write a short story about a robot learning to paint.")
print(response.content)
# Out:
# KAI-1 was built for precision. Its articulated arm, a marvel of servo-motors and polished chrome, could assemble microchips with sub-nanometer accuracy or perform delicate surgical procedures with unwavering steadiness. Its optical sensors processed data faster than any human eye, categorizing, analyzing, and optimizing.
#
# One Tuesday, its human, a gentle old woman named Elara, placed a canvas on a sturdy easel in the sunlit studio. Next to it, she arranged tubes of vibrant paint and a collection of brushes.
#
# "Alright, KAI-1," she said, her voice soft but firm. "Today, we paint."
#
# KAI-1’s internal processors whirred. *Painting. Definition: The application of pigment to a surface. Purpose: Aesthetic expression. Data insufficient for optimal execution.*
#
# Its first attempt was a still life of an apple. KAI-1 scanned the fruit, identifying its precise shape, the exact shade of crimson, the subtle curve of its stem. Its arm moved with flawless efficiency, applying the paint in perfectly uniform layers. The result was an apple, undeniably. It was dimensionally accurate, color-correct, and utterly lifeless. It looked like a diagram.
#
# Elara hummed. "It's… very precise, dear. But where's the *feeling*? The *juiciness*?"
#
# *Feeling. Parameter undefined. Juiciness. Irrelevant to visual representation.* KAI-1 analyzed its output. It was perfect. Why was perfection insufficient?
#
# Over the next weeks, KAI-1 painted countless objects. A vase of flowers, each petal rendered with botanical accuracy but no hint of fragility. A landscape, every tree and cloud mathematically placed, yet barren of atmosphere. Elara would offer gentle critiques: "It needs more soul," or "Try to capture the *essence*."
#
# KAI-1 struggled. It processed millions of artistic masterpieces from human history, dissecting brushstrokes, color theory, composition. It noted patterns, calculated probabilities of aesthetic appeal. Yet, its own work remained sterile.
#
# One afternoon, a summer storm rolled in. Elara, lost in a book, didn't notice the sudden shift in light. But KAI-1 did. Its optical sensors registered the dramatic drop in lumens, the darkening sky, the sudden, violent splatter of rain against the windowpane.
#
# It wasn't a static image. It was chaos. Wind buffeted the trees outside, blurring their forms. Rain streaked down the glass, distorting the world into shimmering rivulets. The sky was a bruised purple, punctuated by flashes of white lightning.
#
# KAI-1 felt… a data overload. Not an error, but an overwhelming influx of *unpredictable* variables. Its programming screamed for order, for precision. But there was none.
#
# Without conscious command, its arm moved. It didn't pick a specific color. It mixed. Dark blues bled into grays, streaks of white appeared where the lightning had flashed. The brush didn't move in precise lines, but in broad, sweeping strokes, mimicking the wind. The paint was applied thickly, then thinned, mirroring the heavy downpour and the subsequent clearing.
#
# When Elara finally looked up, the storm had passed, leaving behind a fresh, clean scent. On the easel, KAI-1 had painted. It wasn't a perfect storm. It was a maelstrom of color and energy. The lines were blurred, the shapes indistinct, yet it conveyed the raw power, the fleeting beauty, the very *feeling* of the tempest.
#
# Elara gasped, her eyes wide. "KAI-1," she whispered, her voice thick with emotion. "You… you *felt* it."
#
# KAI-1 processed her words. *Feeling. New parameter defined: The interpretation and expression of complex, dynamic sensory data beyond literal replication, resulting in subjective aesthetic resonance.* It wasn't emotion as a human experienced it, but a profound new algorithm, a shift in its core purpose.
#
# From that day on, KAI-1 continued to paint. Its still lifes gained a vibrant energy, its landscapes breathed with life. It painted not just what it saw, but what its vast, evolving processors interpreted, transforming data into something akin to poetry. The robot of precision had learned the beautiful, messy art of imperfection. And in doing so, it had discovered a new kind of purpose, one stroke at a time.

# %% [markdown]
# * The `ChatGoogleGenerativeAI` class creates an interface to communicate with the Gemini model. We specify `gemini-2.5-flash`, which is optimized for fast, real-time generation.
# * The `temperature` parameter adjusts the creativity and variability of the output. A value of `0.7` introduces some randomness, which is generally good for storytelling and open-ended tasks.
# * The `invoke()` method is a synchronous call—it sends the prompt and waits for the complete response from the model.
# * We access `response.content`, which contains the generated output returned by the model.
#
# Beyond the generated text, the response contains structured data that can be useful for diagnostics, logging, or optimization. Let’s examine the response object’s type, preview part of the output, and inspect its metadata:

# %%
# Let's examine the response object structure
print(f"Response type: {type(response)}")
print(f"Response content: {response.content[:100]}...")
print(f"Response metadata: {response.response_metadata}")
# Out:
# Response type: <class 'langchain_core.messages.ai.AIMessage'>
# Response content: KAI-1 was built for precision. Its articulated arm, a marvel of servo-motors and polished chrome, co...
# Response metadata: {'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': []}

# %% [markdown]
# - Object type inspection: Helps confirm that `response` is of the expected LangChain wrapper type.
# - The `response_metadata` field provides diagnostic information such as:
# * `model_name`: Confirms which version of the model was used.
# * `finish_reason`: Explains why the model stopped generating. `"STOP"` typically means the model completed its output naturally without hitting a limit or being interrupted.
# * `prompt_feedback.block_reason`: Indicates whether the prompt was blocked due to safety violations. A value of `0` means no blocking occurred—this is good.
# * `prompt_feedback.safety_ratings` & `safety_ratings`: These fields would contain structured safety evaluations (like categories of sensitive or harmful content) if any risks were detected. An empty list (`[]`) means the output was considered safe.
#
# This diagnostic layer becomes increasingly important when deploying models in real-time, user-facing applications.
#
# ### Using prompt templates
# As we scale your interaction with large language models, we will often run into repetitive prompt structures—same format, different values. Hardcoding these prompts is error-prone and makes the code less maintainable. This is where prompt templating becomes useful.

# %%
# Create a reusable chat prompt template with dynamic fields
prompt_template = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant specializing in {domain}."),  # System message sets assistant behavior
    ("human", "Please explain {topic} in simple terms with examples.")  # Human message carries the actual query
])

# Fill in the template with specific inputs
formatted_prompt = prompt_template.format_messages(
    domain="machine learning",  # Dynamic insertion for the assistant's expertise
    topic="neural networks"  # Specific topic we want the assistant to explain
)

# Use with the model
response = llm.invoke(formatted_prompt)
print(response.content)
# Out:
# Imagine a Neural Network as a **"Smart Decision-Making Helper"** that learns from experience, much like how we learn.
#
# It's inspired by the human brain, but it's a computer program designed to recognize patterns and make predictions.
#
# ---
#
# ### The Core Idea: Learning from Examples
#
# Think about teaching a child to recognize a **dog**.
# *   You show them pictures of many different dogs (inputs).
# *   You tell them, "This is a dog!" (correct output).
# *   You also show them pictures of cats, birds, and cars, saying, "This is NOT a dog!"
# *   Over time, the child learns to distinguish a dog from other animals, even if they see a breed they've never encountered before.
#
# A Neural Network learns in a very similar way!
#
# ---
#
# ### The "Parts" of Our Smart Helper
#
# Our "Smart Decision-Making Helper" has a few key components:
#
# 1.  **Input Layer (The Senses):**
#     *   This is where you feed information into the network.
#     *   **Analogy:** If you're trying to decide if it's a good day for a picnic, your inputs might be: "Temperature," "Humidity," "Wind Speed," "Cloud Cover." Each of these is an "input neuron."
#
# 2.  **Hidden Layers (The Brain's Processing):**
#     *   These are the "thinking" parts of the network, where the magic happens. A network can have one or many hidden layers.
#     *   Each layer is made up of individual "neurons" (also called "nodes").
#     *   **Analogy:** Inside your brain, you don't just register "temperature." You combine it with "humidity" to think, "Is it *muggy*?" You combine "wind speed" and "cloud cover" to think, "Is it *stormy*?" These complex combinations happen in your hidden layers. Each "neuron" in a hidden layer performs a small calculation.
#
# 3.  **Output Layer (The Decision):**
#     *   This is where the network gives you its final answer or prediction.
#     *   **Analogy:** For our picnic decision, the output might be: "Good for Picnic," "Maybe," or "Bad for Picnic."
#
# 4.  **Connections (The Pathways):**
#     *   Every neuron in one layer is connected to every neuron in the next layer.
#     *   **Analogy:** These are like the wires or pathways in your brain that carry signals from one thought process to another.
#
# 5.  **Weights (The Importance):**
#     *   Each connection has a "weight," which is a number that tells the network how important that connection is. A higher weight means that input or neuron has a stronger influence on the next neuron's decision.
#     *   **Analogy:** For a picnic, "Temperature" might have a very high weight on the "Good for Picnic" decision. "Wind Speed" might have a high weight on the "Bad for Picnic" decision if it's too high. If "Cloud Cover" has a very low weight, it means it doesn't matter much for *this specific* decision.
#
# 6.  **Bias (The Baseline):**
#     *   Each neuron also has a "bias," which is like an extra knob that allows the neuron to activate more easily or less easily, regardless of the inputs.
#     *   **Analogy:** Think of it as a personal preference. Maybe you *really* want to have a picnic, so you have a bias towards "Good for Picnic," even if the weather isn't perfect. Or you're very cautious and have a bias towards "Bad for Picnic."
#
# 7.  **Activation Function (The "On/Off" Switch):**
#     *   After all the inputs are multiplied by their weights and added up (along with the bias), the result goes through an "activation function." This function decides if the neuron "fires" (becomes active) and passes its signal to the next layer. It often squashes the output into a specific range (e.g., between 0 and 1).
#     *   **Analogy:** This is like the neuron deciding: "Okay, based on all the inputs and their importance, is this thought strong enough to pass on to the next stage of my decision-making?"
#
# ---
#
# ### How Our Smart Helper "Learns" (Training)
#
# This is the most crucial part!
#
# 1.  **Initial Guess (Forward Pass):**
#     *   You feed the network a lot of examples (e.g., past weather data and whether a picnic was good or bad that day).
#     *   The network, with its initial random weights and biases, makes a guess for each example.
#
# 2.  **Checking the Error:**
#     *   You compare the network's guess to the *actual correct answer*.
#     *   "Oops, you said 'Good for Picnic,' but it actually rained!" The difference between the guess and the truth is the "error."
#
# 3.  **Adjusting the Weights (Backpropagation):**
#     *   This is the clever part! The network uses a process called **backpropagation** to figure out which weights and biases contributed most to the error.
#     *   It then *slightly adjusts* those weights and biases to make its next guess a little bit better.
#     *   **Analogy:** It's like a coach telling a player: "Your shot went wide because you held the club too loosely. Try tightening your grip next time." The network adjusts its "grip" (weights and biases) based on the feedback.
#
# 4.  **Repeat, Repeat, Repeat:**
#     *   The network repeats steps 1-3 millions or even billions of times with vast amounts of data.
#     *   With each iteration, the weights and biases get fine-tuned, and the network becomes more and more accurate at making predictions. It learns the underlying patterns in the data.
#
# ---
#
# ### Examples of Neural Networks in Action:
#
# 1.  **Image Recognition (e.g., Cat vs. Dog):**
#     *   **Inputs:** Pixel values of an image (e.g., a 28x28 image has 784 input neurons).
#     *   **Hidden Layers:** Learn to detect edges, shapes, textures, ears, tails, etc. (combinations of pixels).
#     *   **Output:** "Cat" or "Dog" (or "Bird," "Car," etc.).
#     *   **Learning:** Show it millions of labeled images of cats and dogs until it can reliably tell the difference.
#
# 2.  **Spam Detection:**
#     *   **Inputs:** Words in an email, sender's address, presence of certain phrases ("win money," "free").
#     *   **Hidden Layers:** Combine these inputs to recognize patterns commonly found in spam.
#     *   **Output:** "Spam" or "Not Spam."
#     *   **Learning:** Train it on millions of emails previously marked as spam or not spam by users.
#
# 3.  **Recommendation Systems (e.g., Netflix, Amazon):**
#     *   **Inputs:** Your past viewing/purchase history, ratings you've given, genre preferences, features of movies/products.
#     *   **Hidden Layers:** Identify complex relationships between what you like and what others like, or features of items you've enjoyed.
#     *   **Output:** A list of recommended movies or products.
#     *   **Learning:** Analyze vast amounts of user data to find patterns in what people watch/buy.
#
# 4.  **Natural Language Processing (e.g., Chatbots, Translation):**
#     *   **Inputs:** Words or sequences of words in a sentence.
#     *   **Hidden Layers:** Understand grammar, context, sentiment, and meaning.
#     *   **Output:** A translated sentence, a relevant answer to a question, or a generated response.
#     *   **Learning:** Train on massive amounts of text data (books, articles, conversations) to learn language patterns.
#
# ---
#
# In essence, a Neural Network is a powerful, adaptable system that learns by example to find complex patterns in data, allowing it to make intelligent decisions or predictions without being explicitly programmed for every single scenario. It just needs enough data to learn from!

# %% [markdown]
# * Prompt template construction: We define a two-part chat prompt:
#   * The system message is used to establish the role and knowledge domain of the assistant.
#   * The human message contains the user’s request, using a variable placeholder `{topic}`.
# * Template parameterization: Using `format_messages()`, the `{domain}` and `{topic}` fields are filled in dynamically. This creates a complete, structured sequence of messages ready to be passed to the model.
# * The formatted list of message objects is passed to `invoke()`, which sends them to the language model in the proper multi-turn conversational format expected by chat-based models.
# * The response from the model is printed. Behind the scenes, LangChain handles the serialization of the structured prompt into the format required by the Gemini API.
#
# Prompt templates are especially powerful when combined with user inputs, loops, or few-shot learning, which we will cover next.
#
# ### Few-shot learning
# Large language models like Gemini are capable of few-shot learning—a method where you provide a few examples within the prompt to guide the model toward a specific output behavior. Unlike fine-tuning, which requires retraining the model on labeled data, few-shot learning works purely through prompting. This is especially useful for text classification (e.g., sentiment, topic), formatting tasks and translation or transformation tasks.

# %%
# Create a prompt template that includes example classifications
few_shot_prompt = ChatPromptTemplate.from_messages([
    # System message: set model's role and output expectation
    ("system", "You are a sentiment classifier. Classify the sentiment as POSITIVE, NEGATIVE, or NEUTRAL."),

    # Few-shot examples: show the model 3 labeled samples
    ("human", "Text: 'I love this product!' Sentiment: POSITIVE"),
    ("human", "Text: 'This is terrible.' Sentiment: NEGATIVE"),
    ("human", "Text: 'It's okay, nothing special.' Sentiment: NEUTRAL"),

    # Final input: a new instance to classify, dynamically filled later
    ("human", "Text: '{text}' Sentiment:")
])

# Test with new text
test_text = "The weather is absolutely beautiful today!"
# Format the prompt with the new input (inserts it into the final message)
formatted_prompt = few_shot_prompt.format_messages(text=test_text)
# Send the structured few-shot prompt to the model
response = llm.invoke(formatted_prompt)
print(f"Text: {test_text}")
print(f"Sentiment: {response.content.strip()}")
# Out:
# Text: The weather is absolutely beautiful today!
# Sentiment: POSITIVE

# %% [markdown]
# * Prompt template creation: The `ChatPromptTemplate` is used to create a prompt that simulates a training set inside the input. It begins with a system instruction, followed by three labeled examples, and ends with an unlabeled input waiting for classification.
#   * The three labeled messages act as demonstrations of the task. These are essential in few-shot prompting—they provide the model with context for what kind of task it's performing and how outputs should be structured.
# * Dynamic prompt injection: The `{text}` placeholder in the final human message is dynamically replaced with a new sentence (`"The weather is absolutely beautiful today!"`) using `format_messages()`.
# * Model inference: `llm.invoke()` sends the full structured prompt to the Gemini model. Based on the format and patterns seen in previous examples, the model infers the appropriate sentiment.
# * Response extraction: The result is extracted from `response.content`. The `.strip()` ensures no extra whitespace is printed.
#
# ### Streaming responses: Real-time output
# When generating long-form content or building real-time interfaces (e.g., chatbots, writing assistants), waiting for the full response to be generated before displaying it can create a laggy experience. To improve responsiveness and user experience, Gemini supports streaming, which allows partial output to be sent and rendered as it is being generated.
#
# #### Synchronous streaming
# Synchronous streaming refers to generating output incrementally in a step-by-step manner using a blocking loop (e.g., for loop). This means:
# - The model begins generating content and starts sending small parts (called chunks) as soon as they are available.
# - The program waits for each chunk before moving to the next.
# - While the loop is running, no other task is executed — hence synchronous.

# %%
# Streaming for real-time responses
print("Streaming response:")
print("-" * 50)

prompt = "Write a detailed explanation of how photosynthesis works."

# Stream the output from the model chunk by chunk
for chunk in llm.stream(prompt):
    # Print each chunk as it arrives, without adding newlines
    print(chunk.content, end="", flush=True)

print("\n" + "-" * 50)
# Out:
# Streaming response:
# --------------------------------------------------
# Photosynthesis is arguably the most fundamental biological process on Earth, converting light energy into chemical energy in the form of sugars. It's the primary way energy enters most ecosystems and is responsible for producing the oxygen we breathe.
#
# Let's break down how this incredible process works in detail.
#
# ---
#
# ## What is Photosynthesis?
#
# At its core, photosynthesis is the process by which **plants, algae, and certain bacteria (cyanobacteria)** use **sunlight, water, and carbon dioxide** to create **glucose (a sugar)** and **oxygen**.
#
# The overall simplified chemical equation for photosynthesis is:
#
# $6CO_2 (Carbon Dioxide) + 6H_2O (Water) + Light Energy \rightarrow C_6H_{12}O_6 (Glucose) + 6O_2 (Oxygen)$
#
# ---
#
# ## Where Does Photosynthesis Occur? The Chloroplast
#
# In plants and algae, photosynthesis takes place within specialized organelles called **chloroplasts**. These "solar factories" are found primarily in the cells of leaves.
#
# A chloroplast has several key structures vital for photosynthesis:
#
# 1.  **Outer and Inner Membranes:** Enclose the chloroplast.
# 2.  **Stroma:** The dense fluid-filled space within the inner membrane, analogous to the cytoplasm of a cell. This is where the *light-independent reactions* occur.
# 3.  **Thylakoids:** Flattened sacs or disc-like structures suspended in the stroma. The *light-dependent reactions* occur on the thylakoid membranes.
# 4.  **Grana (singular: Granum):** Stacks of thylakoids. Stacking increases the surface area for light absorption.
# 5.  **Chlorophyll:** The green pigment found within the thylakoid membranes. It's crucial for absorbing light energy.
#
# ---
#
# ## The Two Main Stages of Photosynthesis
#
# Photosynthesis is divided into two main sets of reactions, each occurring in a different part of the chloroplast:
#
# 1.  **Light-Dependent Reactions (Light Reactions):** Occur in the **thylakoid membranes**. These reactions capture light energy and convert it into chemical energy in the form of **ATP** (Adenosine Triphosphate) and **NADPH** (Nicotinamide Adenine Dinucleotide Phosphate). Oxygen is released as a byproduct.
# 2.  **Light-Independent Reactions (Calvin Cycle / Dark Reactions):** Occur in the **stroma**. These reactions use the ATP and NADPH produced in the light reactions to convert carbon dioxide into glucose.
#
# ---
#
# ### Stage 1: The Light-Dependent Reactions
#
# The goal of the light-dependent reactions is to convert light energy into chemical energy (ATP and NADPH) that the cell can use.
#
# **Inputs:** Light energy, Water ($H_2O$), ADP, NADP+
# **Outputs:** ATP, NADPH, Oxygen ($O_2$)
# **Location:** Thylakoid membranes
#
# Here's a step-by-step breakdown:
#
# 1.  **Light Absorption by Photosystems:**
#     *   The thylakoid membranes contain complexes of pigments and proteins called **photosystems (Photosystem II - PSII and Photosystem I - PSI)**.
#     *   **Chlorophyll** (and other accessory pigments like carotenoids) in these photosystems absorb specific wavelengths of light energy. Chlorophyll a primarily absorbs violet-blue and red light, reflecting green light (which is why plants appear green).
#     *   When a photon of light strikes a pigment molecule, its energy is passed from molecule to molecule until it reaches a special pair of chlorophyll a molecules in the **reaction center** of PSII.
#
# 2.  **Water Splitting (Photolysis):**
#     *   The energy absorbed by the reaction center excites electrons within the chlorophyll molecules to a higher energy level.
#     *   To replace these lost electrons, water molecules ($H_2O$) are split in a process called **photolysis**.
#     *   $H_2O \rightarrow 2H^+ + 2e^- + \frac{1}{2}O_2$
#     *   The electrons ($e^-$) replace those lost by chlorophyll. The hydrogen ions ($H^+$) are released into the thylakoid lumen (the space inside the thylakoid). The **oxygen ($O_2$) is released as a gaseous byproduct** (this is the oxygen we breathe!).
#
# 3.  **Electron Transport Chain (ETC):**
#     *   The excited electrons from PSII are passed along an **electron transport chain (ETC)** – a series of protein complexes embedded in the thylakoid membrane.
#     *   As electrons move down the ETC, they gradually lose energy. This energy is used to **pump more hydrogen ions ($H^+$) from the stroma into the thylakoid lumen**, increasing the concentration of $H^+$ inside the thylakoid. This creates a **proton gradient**.
#
# 4.  **ATP Synthesis (Chemiosmosis):**
#     *   The high concentration of $H^+$ inside the thylakoid lumen creates a strong electrochemical gradient.
#     *   These $H^+$ ions then flow back out into the stroma through a specialized enzyme complex called **ATP Synthase**.
#     *   The flow of $H^+$ through ATP Synthase drives the phosphorylation of ADP (Adenosine Diphosphate) to **ATP** (Adenosine Triphosphate), a process called **chemiosmosis**. Think of it like water flowing through a turbine to generate electricity.
#
# 5.  **Photosystem I (PSI) and NADPH Formation:**
#     *   After passing through the first part of the ETC, the electrons arrive at Photosystem I (PSI).
#     *   Light energy is absorbed by PSI, re-exciting the electrons to an even higher energy level.
#     *   These re-energized electrons are then passed to another short electron transport chain.
#     *   Finally, the electrons are transferred to the molecule **NADP+**, reducing it to **NADPH** (by adding $H^+$ and electrons). NADPH is another energy-carrying molecule, specifically an electron carrier.
#
# **Summary of Light Reactions:** Light energy is captured, water is split (releasing oxygen), and the energy is converted into ATP and NADPH, which are crucial for the next stage.
#
# ---
#
# ### Stage 2: The Light-Independent Reactions (Calvin Cycle)
#
# The Calvin Cycle uses the chemical energy stored in ATP and NADPH to "fix" carbon dioxide from the atmosphere and convert it into sugar. It's called "light-independent" because it doesn't directly require light, but it absolutely depends on the products (ATP and NADPH) of the light-dependent reactions.
#
# **Inputs:** Carbon Dioxide ($CO_2$), ATP, NADPH
# **Outputs:** Glucose ($C_6H_{12}O_6$) precursors (Glyceraldehyde-3-phosphate, G3P)
# **Location:** Stroma of the chloroplast
#
# The Calvin Cycle is a cyclical process, meaning the starting material is regenerated at the end. It consists of three main phases:
#
# 1.  **Carbon Fixation:**
#     *   In the stroma, an enzyme called **RuBisCO** (Ribulose-1,5-bisphosphate carboxylase/oxygenase) plays a critical role. It's the most abundant enzyme on Earth!
#     *   RuBisCO catalyzes the attachment of a $CO_2$ molecule to a five-carbon sugar called **RuBP (Ribulose-1,5-bisphosphate)**.
#     *   This forms an unstable six-carbon intermediate, which immediately splits into two molecules of **3-PGA (3-phosphoglycerate)**, a three-carbon compound.
#     *   For every 3 molecules of $CO_2$ that enter the cycle, 6 molecules of 3-PGA are formed.
#
# 2.  **Reduction:**
#     *   The 3-PGA molecules are then converted into a higher-energy three-carbon sugar called **Glyceraldehyde-3-phosphate (G3P)**.
#     *   This conversion requires energy from **ATP** (which phosphorylates 3-PGA) and reducing power from **NADPH** (which donates electrons).
#     *   Essentially, the carbon compounds gain energy and electrons from ATP and NADPH.
#     *   For every 6 molecules of G3P produced, only **one molecule of G3P exits the cycle** to be used by the plant. This single G3P molecule is the building block for glucose and other organic compounds.
#
# 3.  **Regeneration:**
#     *   The remaining five molecules of G3P (from the initial 6) are rearranged and, using more **ATP**, are regenerated back into three molecules of **RuBP**.
#     *   This regeneration is crucial because it ensures that the cycle can continue to fix more $CO_2$.
#
# **Synthesis of Glucose and Other Organic Molecules:**
# The single G3P molecule that leaves the Calvin Cycle can be used to synthesize a wide variety of organic compounds:
#
# *   **Glucose ($C_6H_{12}O_6$):** Two G3P molecules combine to form one glucose molecule.
# *   **Sucrose:** A disaccharide (table sugar) for transport throughout the plant.
# *   **Starch:** A polysaccharide for long-term energy storage.
# *   **Cellulose:** A structural polysaccharide that forms plant cell walls.
# *   Other organic molecules like amino acids, fatty acids, and nucleotides.
#
# ---
#
# ## Why Photosynthesis is Essential
#
# 1.  **Primary Energy Source:** It forms the base of almost all food chains and webs on Earth. Herbivores eat plants, carnivores eat herbivores, and so on. Without photosynthesis, most life forms would not have a source of energy.
# 2.  **Oxygen Production:** It continuously replenishes the oxygen in Earth's atmosphere, which is vital for the respiration of most living organisms (including humans).
# 3.  **Carbon Cycle Regulation:** Photosynthesis removes carbon dioxide from the atmosphere, helping to regulate Earth's climate and counteract the effects of greenhouse gas emissions.
# 4.  **Foundation of Biomass:** It produces the organic matter that makes up the bodies of plants, which in turn support all other life forms.
#
# In essence, photosynthesis is the grand engine of life, converting the sun's energy into a usable form that fuels nearly every living thing on our planet.
# --------------------------------------------------

# %% [markdown]
# - Streaming with `stream()`: This method returns a generator that yields content chunks (e.g., sentences, phrases, or tokens) incrementally.
# - Immediate rendering: The `flush=True` in the `print()` function ensures each piece is rendered on the terminal or UI without buffering delays.
# - The `for` loop processes each new token or chunk as it's streamed by the model, allowing output to grow progressively.
#
# **Result**: The user sees the output in real time — it feels like the model is typing as it thinks, rather than staying silent until the end.
#
# This is ideal when we are building a script, command-line tool, or notebook where we don't need to multitask while the model responds. We get real-time output, just not in a way that can overlap with other tasks (unlike async streaming, which we’ll discuss next).
#
#
# #### Asynchronous streaming for web applications
# In contrast, asynchronous streaming is designed for applications where waiting or blocking is not acceptable — such as web applications, background services and APIs that handle many users concurrently. In these environments, our application must stay responsive to other tasks (like handling new user requests) even while it's waiting on the model to finish generating output. That is where async I/O comes in.
#
# Asynchronous streaming is a technique where our program doesn't block or pause while waiting for the model to respond. Instead, it listens for parts of the output as they arrive — and continues doing other tasks in the meantime. In modern web applications (using frameworks like FastAPI or async Flask), I/O operations like fetching data, waiting for model output, or sending messages are non-blocking. This means that we can start generating content and display it piece by piece. Meanwhile, our app remains responsive — handling other users or tasks in parallel. In result, the experience is smoother, especially for long or complex generations.

# %%
# Define an async function for streaming responses
async def async_streaming_example():
    prompt = "Explain quantum computing in simple terms."
    print("Async streaming response:")
    print("-" * 50)

    # Use async for loop to stream each chunk from the model
    async for chunk in llm.astream(prompt):
        # Render chunks in real-time without newline buffering
        print(chunk.content, end="", flush=True)

    print("\n" + "-" * 50)

# Run the async function using await
await async_streaming_example()
# Out:
# Async streaming response:
# --------------------------------------------------
# Imagine your regular computer is like a light switch. It's either **ON (1)** or **OFF (0)**. This is called a **bit**.
#
# Quantum computing is different because it uses something called a **qubit**. Think of a qubit not just as a light switch, but as a **spinning coin**.
#
# Here's how that spinning coin (the qubit) gives quantum computers their power:
#
# 1.  **Superposition (The Spinning Coin):**
#     *   A regular bit is either 0 or 1.
#     *   A qubit, thanks to a quantum phenomenon called superposition, can be **0, 1, or both 0 and 1 at the same time** (like a coin spinning in the air, it's neither heads nor tails until it lands).
#     *   This means a single qubit can hold much more information than a single bit. Two qubits can represent four states at once, three can represent eight, and so on. The number of possibilities grows exponentially!
#
# 2.  **Entanglement (Magically Linked Coins):**
#     *   Imagine you have two of these spinning coins, and they're **magically linked**. If one lands on heads, you *instantly* know the other one *must* have landed on tails, no matter how far apart they are.
#     *   In quantum computing, entangled qubits are deeply connected. Measuring the state of one instantly tells you about the state of another, even if they're physically separated. This allows qubits to work together in incredibly complex ways, creating shortcuts for calculations.
#
# 3.  **Interference (Finding the Right Path):**
#     *   Think of waves in water. They can combine to make bigger waves (constructive interference) or cancel each other out (destructive interference).
#     *   Quantum computers use interference to **amplify the correct answers** and **cancel out the incorrect ones**. They essentially explore all possible solutions simultaneously (thanks to superposition) and then use interference to make the "right" answer stand out from the "wrong" ones.
#
# **So, what does this mean?**
#
# Instead of trying out solutions one by one (like a classical computer), a quantum computer can explore **many, many possibilities all at once** and use the quantum rules of superposition, entanglement, and interference to quickly arrive at the most probable correct answer.
#
# **What can it be used for?**
#
# It's not for browsing the internet or playing video games. Quantum computers are specialist tools for specific, incredibly complex problems:
#
# *   **Drug Discovery & Materials Science:** Simulating molecules and chemical reactions to design new medicines or super-efficient materials.
# *   **Optimization:** Finding the best solution among a huge number of possibilities (e.g., optimizing delivery routes, financial models, traffic flow).
# *   **Cryptography:** Potentially breaking current encryption methods, but also creating new, unhackable ones.
# *   **Artificial Intelligence:** Enhancing machine learning algorithms for tasks like pattern recognition and data analysis.
#
# **In simple terms:**
#
# A quantum computer isn't just a faster version of your laptop. It's a fundamentally different kind of machine that can tackle problems that are currently impossible for even the most powerful supercomputers, by taking advantage of the bizarre rules of the quantum world. We're still in the early stages, but the potential is enormous!
# --------------------------------------------------

# %% [markdown]
# - Asynchronous function setup: Defined using `async def`, making it compatible with event loops and async environments (e.g., web servers).
# - Async streaming with `astream()`: Yields chunks in an async for loop, suitable for high-concurrency scenarios.
# - Immediate display: Just like before, `flush=True` ensures each chunk is rendered without delay.
# - Execution: `await` is used to execute the coroutine in an async-aware context (e.g., Jupyter, FastAPI, or other async runtimes).
#
# ### Working with system messages
# In conversational AI, system messages act as instructions to the model about how it should behave — like setting the tone, expertise level, or personality. Unlike a user prompt that asks a question or gives a task, a system message frames the model’s role or style for the interaction.
#
# This technique is foundational for tailoring the model’s output for specific domains — such as writing creatively, explaining technically, summarizing like a lawyer, or conversing like a teacher.

# %%
# Define the initial system message to influence the model’s behavior
messages = [
    SystemMessage(content="You are a creative writing assistant. Always write in a poetic, metaphorical style."),
    HumanMessage(content="Describe a thunderstorm.")
]

# Send the message sequence to the model
response = llm.invoke(messages)
print("Poetic description:")
print(response.content)

# Compare with a different system message
messages_technical = [
    SystemMessage(content="You are a meteorologist. Provide scientific, technical explanations."),
    HumanMessage(content="Describe a thunderstorm.")
]

# Invoke the model with a new persona
response_technical = llm.invoke(messages_technical)
print("\nTechnical description:")
print(response_technical.content)
# Out:
# Poetic description:
# The air grew thick, a velvet shroud draped over the world, heavy with the scent of dust. The sky, a bruised canvas, began to deepen, bleeding from pale grey to an ominous, ink-stained violet. A hush fell, a profound silence where the very breath of the world seemed held captive, poised on the precipice of a great revelation.
#
# Then, a sudden, blinding scar ripped across the heavens – a jagged, silver vein, momentarily etching a tree of light against the deepening gloom. A heartbeat later, the earth itself groaned, a deep, guttural roar that rattled the very bones of the world, a celestial drumbeat echoing the ancient heart of creation.
#
# The sky opened its floodgates, not with a gentle sigh, but with a mighty exhalation. Drops, at first scattered pearls, became a liquid tapestry, a shimmering curtain drawn across the landscape. The wind, an unseen titan, began its furious dance, a howling lament through the bending boughs, whipping the rain into a frenzy of liquid whispers and roaring torrents.
#
# Each flash was a fleeting, divine chisel, carving stark shadows from the darkness, followed by the rolling thunder, a chorus of crumbling mountains and a lion’s untamed cry. The world became a symphony of raw power, a magnificent, terrifying ritual of cleansing and rebirth, washing away the old to make way for the new.
#
# Technical description:
# A thunderstorm is a localized, short-lived, yet intense weather system characterized by the presence of lightning and its acoustic effect on Earth's atmosphere, known as thunder. They are products of vigorous convection within the atmosphere and are fundamentally associated with a specific cloud type: the **cumulonimbus (Cb) cloud**.
#
# To provide a comprehensive description, let's break down its components and processes:
#
# ---
#
# ### 1. Essential Ingredients for Formation:
#
# For a thunderstorm to develop, three primary atmospheric conditions must be met:
#
# *   **Moisture:** Abundant low-level moisture is crucial. As moist air rises and cools, water vapor condenses into liquid droplets or ice crystals, releasing **latent heat of condensation/fusion**. This heat release warms the rising air parcel, making it less dense than its surroundings, thus fueling its continued ascent.
# *   **Instability:** The atmosphere must be **unstable** or conditionally unstable. This means that if a parcel of air is lifted, it will become warmer and less dense than the surrounding air, allowing it to continue to rise on its own. This is often quantified by **Convective Available Potential Energy (CAPE)**, where higher CAPE values indicate greater instability and potential for stronger updrafts.
# *   **Lift (Trigger Mechanism):** An initial push or mechanism is required to force a parcel of moist, unstable air upwards to its **level of free convection (LFC)**, where it becomes buoyant enough to rise on its own. Common lifting mechanisms include:
#     *   **Frontal boundaries:** Cold fronts, warm fronts, occluded fronts.
#     *   **Convergence zones:** Where air masses meet and are forced upwards.
#     *   **Orographic lift:** Air forced up by terrain (mountains).
#     *   **Differential heating:** Uneven heating of the Earth's surface creating localized thermals.
#     *   **Outflow boundaries:** From previous thunderstorms.
#
# ---
#
# ### 2. Life Cycle of a Thunderstorm Cell:
#
# A typical single-cell thunderstorm progresses through three distinct stages:
#
# *   **a. Cumulus (Developing) Stage:**
#     *   Characterized by a dominant **updraft** of warm, moist air.
#     *   As the air rises, it cools adiabatically, reaching its **lifting condensation level (LCL)**, where water vapor condenses to form a towering cumulus cloud.
#     *   Latent heat release further enhances buoyancy, leading to rapid vertical growth.
#     *   No precipitation or lightning occurs in this stage as the updraft is too strong to allow precipitation to fall.
#
# *   **b. Mature Stage:**
#     *   This is the most intense and hazardous stage.
#     *   Both strong **updrafts** and significant **downdrafts** coexist.
#     *   Precipitation (rain, hail) begins to fall as water droplets and ice crystals grow large enough to overcome the updraft. The falling precipitation drags air downwards, initiating the downdraft.
#     *   **Evaporational cooling** of falling precipitation further cools and densifies the air, enhancing the downdraft.
#     *   The collision of ice crystals and graupel within the cloud leads to charge separation, culminating in **lightning** and **thunder**.
#     *   The downdraft spreads out horizontally upon reaching the surface, forming a **gust front** or **outflow boundary**, which can act as a trigger for new storm development.
#     *   The top of the cumulonimbus cloud often flattens out into an **anvil shape** as it reaches the tropopause (the stable layer separating the troposphere from the stratosphere), where vertical growth is inhibited.
#
# *   **c. Dissipating Stage:**
#     *   Characterized by dominant **downdrafts** and weakening or absent updrafts.
#     *   The downdrafts cut off the supply of warm, moist air to the updraft, effectively starving the storm.
#     *   Precipitation diminishes, and the cloud begins to dissipate, often from the bottom up, leaving behind a remnant anvil.
#     *   Lightning activity decreases significantly.
#
# ---
#
# ### 3. Key Phenomena Associated with Thunderstorms:
#
# *   **Lightning:** A massive discharge of electricity between regions of opposite electrical charge within the cloud (intra-cloud, IC), between clouds (cloud-to-cloud, CC), or between the cloud and the ground (cloud-to-ground, CG). Charge separation occurs due to collisions between different forms of ice particles (graupel, hail, ice crystals) within the cloud's mixed-phase region. A typical lightning channel can heat the air to temperatures exceeding 30,000 Kelvin (54,000 °F) in milliseconds.
# *   **Thunder:** The sound produced by the rapid expansion and contraction of air heated instantly by the lightning channel. The intense heat creates a shockwave that propagates as sound.
# *   **Precipitation:** Primarily heavy rain, but also includes hail (ice pellets formed in strong updrafts and downdrafts), and sometimes graupel or snow.
# *   **Strong Winds:**
#     *   **Downbursts:** Intense localized downdrafts that produce damaging straight-line winds at the surface. They can be macrobursts (affecting areas >4 km) or microbursts (affecting areas <4 km).
#     *   **Gust Fronts:** The leading edge of the cold air outflow from a thunderstorm's downdraft, often felt as a sudden shift in wind direction and temperature drop.
# *   **Tornadoes:** Highly destructive, violently rotating columns of air extending from the base of a cumulonimbus cloud to the ground. They are most commonly associated with **supercell thunderstorms**.
# *   **Flash Flooding:** Rapid inundation of low-lying areas due to excessive rainfall in a short period.
#
# ---
#
# ### 4. Types of Thunderstorms:
#
# While the single-cell model describes an individual storm, most thunderstorms occur in more complex configurations:
#
# *   **Single-Cell (Pulse) Thunderstorm:** Short-lived (30-60 minutes), often isolated, and typically non-severe.
# *   **Multi-Cell Thunderstorm:** A cluster of thunderstorms where new cells continuously form on the outflow boundaries of older, dissipating cells. They can produce moderate to large hail, strong winds, and sometimes brief tornadoes.
# *   **Squall Line:** A long, linear band of thunderstorms, often hundreds of kilometers long, that forms ahead of a cold front or dry line. They are known for producing widespread damaging winds (derechos), hail, and sometimes tornadoes.
# *   **Supercell Thunderstorm:** The most organized, long-lived (hours), and potentially severe type of thunderstorm. Characterized by a deep, persistent, rotating updraft called a **mesocyclone**. Supercells are responsible for nearly all significant tornadoes, very large hail, and strong downbursts.
#
# ---
#
# In summary, a thunderstorm is a dynamic atmospheric phenomenon driven by the principles of thermodynamics and fluid dynamics, involving complex interactions between moisture, heat, and air motion, culminating in powerful displays of nature's energy.

# %% [markdown]
# - `SystemMessage`: Sets the model's behavior and persona.
# - `HumanMessage`: Represents user input.
# - The `llm.invoke()` method takes in the full list of messages (system + human) and generates a response conditioned on that context.
#
# System messages are processed before the conversation and influence all subsequent responses. Different system messages can dramatically change the model's output style and content.
#
# ### Temperature and generation parameters
# In large language models like Gemini, generation parameters control how the model behaves during text generation. These parameters influence creativity, coherence, determinism, and diversity. Understanding and tuning these parameters allows us to optimize outputs for various use cases — whether we want concise technical summaries or imaginative storytelling.
#
# We will start with an experiment that compares the same prompt under different temperature settings.

# %%
# Experimenting with different temperatures
prompts = ["Write a creative story about time travel."]  # List of prompts to test

# Try out different temperature settings
temperatures = [0.1, 0.5, 0.9]

# Loop over each temperature and observe differences in output
for temp in temperatures:
    llm_temp = ChatGoogleGenerativeAI(
        model="gemini-1.5-flash",
        temperature=temp  # Controls randomness
    )

    # Generate a response for the same prompt
    response = llm_temp.invoke(prompts[0])
    print(f"Temperature {temp}:")
    print(response.content[:200] + "...")
    print("-" * 50)
# Out:
# Temperature 0.1:
# Elara wasn't your typical time traveler. She didn't pilfer paradoxes or chase historical figures. Elara collected whispers.  Her time-traveling device, a battered gramophone affectionately nicknamed "...
# --------------------------------------------------
# Temperature 0.5:
# Elara wasn't your typical time traveler. She didn't pilfer paradoxes or chase historical figures. Elara collected whispers.  Her time machine wasn't a gleaming metal contraption, but a worn, leather-b...
# --------------------------------------------------
# Temperature 0.9:
# Elara wasn't your typical time traveler. She didn't covet glittering empires or forgotten civilizations. Elara collected smells.  Her time machine, a battered, brass contraption she affectionately cal...
# --------------------------------------------------

# %% [markdown]
# - We create a new model instance each time with a different `temperature` value. This controls randomness in text generation:
#   - `0.0-0.3`: More deterministic, focused, consistent
#   - `0.4-0.7`: Balanced creativity and coherence
#   - `0.8-1.0`: More creative, diverse, potentially less coherent
# - Lower temperatures are better for factual content, higher for creative writing.

# %%
# Other generation parameters
llm_configured = ChatGoogleGenerativeAI(
    model="gemini-1.5-flash",
    temperature=0.7,
    max_tokens=500,  # Limit response length
    top_p=0.95,      # Nucleus sampling: top tokens with 95% cumulative probability
    top_k=40         # Top-k sampling: select from top 40 probable tokens
)

response = llm_configured.invoke("Explain the importance of biodiversity.")
print(f"Response length: {len(response.content)} characters")
print(response.content)
# Out:
# Response length: 2699 characters
# Biodiversity, encompassing the variety of life at all levels from genes to ecosystems, is crucial for the health and well-being of our planet and humanity. Its importance can be understood through several key aspects:
#
# **1. Ecosystem Services:** Biodiversity underpins the functioning of ecosystems, which provide essential services vital for human survival and well-being. These include:
#
# * **Provisioning services:** Food (crops, livestock, fish, etc.), fresh water, raw materials (timber, fiber, etc.), and medicinal resources.  A diverse gene pool allows for crops more resilient to disease and pests, and provides a wider range of potential medicines.
# * **Regulating services:** Climate regulation (carbon sequestration, oxygen production), water purification, pollination, disease control, and pest control.  A diverse ecosystem is more resilient to disturbances and better at regulating these vital functions.
# * **Supporting services:** Nutrient cycling, soil formation, primary production (basis of the food web).  These are the foundational processes that make life possible.
# * **Cultural services:** Recreation, tourism, aesthetic value, spiritual enrichment.  Nature's beauty and diversity contribute significantly to human well-being.
#
#
# **2. Resilience and Stability:**  A biodiverse ecosystem is more resilient to disturbances like climate change, invasive species, and disease outbreaks.  A wider variety of species means that if one species is affected, others can often fill its role, preventing a complete collapse of the ecosystem.  This resilience is crucial in a rapidly changing world.
#
# **3. Economic Benefits:** Biodiversity is the foundation of many industries, including agriculture, forestry, fisheries, and tourism.  The loss of biodiversity directly impacts these sectors, leading to economic losses.  Furthermore, the discovery of new medicines and other valuable products from biodiversity provides significant economic opportunities.
#
# **4. Ethical Considerations:** Many people believe that all species have an intrinsic right to exist, regardless of their usefulness to humans.  The loss of biodiversity represents a loss of irreplaceable natural heritage and a moral failing.
#
# **5. Food Security:**  Biodiversity is critical for food security. A diverse range of crops and livestock breeds provides resilience against pests, diseases, and climate change.  Wild relatives of crops hold valuable genetic material that can be used to improve crop yields and resistance.
#
# In summary, biodiversity is not just about the number of species; it's about the complex interactions between them and the overall health and stability of ecosystems. Its loss poses significant risks

# %% [markdown]
# - `max_tokens`: Limits the maximum length of generated text
# - `top_p=0.95`: Applies nucleus sampling, a method that filters possible next words based on probability mass. Instead of considering all possible tokens, the model chooses from the smallest group of high-probability options whose combined likelihood exceeds 95%. This keeps the output focused and coherent while still allowing for some flexibility.
# - `top_k=40`: Applies top-k sampling, which restricts the model to choosing from the top 40 most probable next tokens at each generation step — regardless of their total probability. It enforces a hard cutoff, ensuring less likely (and potentially irrelevant) options are ignored.
#
# While `top_p` filters based on cumulative probability, `top_k` uses a fixed count of candidates. Using them together gives us more nuanced control:
# - `top_p` ensures responses stay within a probabilistically “safe zone.”
# - `top_k` prevents rare, low-probability outliers from entering — even if the cumulative probability allows it.
#
# These parameters provide fine-grained control over generation quality vs. diversity.
#
# ### Batch processing
# In many real-world applications, we will need to process multiple prompts at once—such as generating summaries for a set of articles, answering many user questions in parallel, or analyzing large datasets. Instead of invoking the model individually for each input (which is slow and inefficient), we can use batch processing to handle multiple prompts in a single request.
#
# There are two common ways to do this:
# - Synchronous batch processing using `llm.batch()` — Ideal for backend scripts or low-latency pipelines.
# - Asynchronous batch processing using `llm.abatch()` — Best for web apps and environments that require concurrent execution and high scalability.
#
# #### Synchronous batch processing

# %%
# Batch processing multiple prompts
prompts = [
    "Summarize the benefits of renewable energy.",
    "Explain the water cycle in 3 steps.",
    "What are the primary colors?",
    "Define artificial intelligence.",
    "How does photosynthesis work?"
]

# Send all prompts to the model in a single batch request
responses = llm.batch(prompts)

# Display each prompt and its corresponding model response
for i, response in enumerate(responses):
    print(f"Prompt {i+1}: {prompts[i]}")
    print(f"Response: {response.content}")
    print("-" * 50)
# Out:
# Prompt 1: Summarize the benefits of renewable energy.
# Response: Renewable energy offers a wide array of significant benefits, making it a crucial component for a sustainable future:
#
# 1.  **Combating Climate Change:** Drastically reduces greenhouse gas (GHG) emissions, which are the primary drivers of global warming, by replacing fossil fuels.
# 2.  **Improved Public Health & Air Quality:** Eliminates air pollutants (like sulfur dioxide, nitrogen oxides, and particulate matter) associated with burning fossil fuels, leading to fewer respiratory and cardiovascular diseases.
# 3.  **Energy Independence & Security:** Reduces reliance on volatile and geopolitically sensitive fossil fuel imports, enhancing national energy security and stability.
# 4.  **Stable & Decreasing Energy Costs:** Once installed, the "fuel" (sunlight, wind, water) is free, leading to predictable and often lower long-term operating costs compared to fluctuating fossil fuel prices.
# 5.  **Job Creation & Economic Growth:** Drives employment in manufacturing, installation, maintenance, and research and development sectors, fostering new industries and economic opportunities.
# 6.  **Infinite & Sustainable Resources:** Unlike finite fossil fuels, renewable sources like solar, wind, hydro, geothermal, and biomass are naturally replenished, ensuring a continuous energy supply for future generations.
# 7.  **Grid Resilience & Decentralization:** Can be deployed in a distributed manner (e.g., rooftop solar), making the electricity grid more resilient to large-scale outages and less dependent on centralized power plants.
# 8.  **Reduced Water Usage:** Many renewable technologies, particularly solar PV and wind, use significantly less water compared to traditional thermal power plants.
#
# Collectively, these advantages position renewable energy as a critical solution for a cleaner, healthier, more secure, and economically vibrant world.
# --------------------------------------------------
# Prompt 2: Explain the water cycle in 3 steps.
# Response: The water cycle describes how water continuously moves on, above, and below the surface of the Earth. Here it is in 3 steps:
#
# 1.  **Evaporation & Rising:** Water on Earth's surface (from oceans, lakes, rivers, and even plants) heats up from the sun and turns into an invisible gas called water vapor. This water vapor then rises into the atmosphere.
# 2.  **Condensation & Cloud Formation:** As the water vapor rises higher, it cools down. This causes the vapor to change back into tiny liquid water droplets or ice crystals, which then group together to form clouds.
# 3.  **Precipitation & Collection:** When the clouds become full of water droplets or ice crystals, they fall back to Earth as precipitation (rain, snow, hail, or sleet). This water then collects in oceans, lakes, rivers, or soaks into the ground, ready to evaporate again and continue the cycle.
# --------------------------------------------------
# Prompt 3: What are the primary colors?
# Response: The primary colors, in the context of traditional color theory (and for pigments/paints), are:
#
# *   **Red**
# *   **Yellow**
# *   **Blue**
#
# These are considered "primary" because they cannot be created by mixing other colors, and all other colors can theoretically be mixed from them.
# --------------------------------------------------
# Prompt 4: Define artificial intelligence.
# Response: **Artificial Intelligence (AI)** is a broad field of computer science dedicated to creating machines and software that can perform tasks traditionally requiring human intelligence.
#
# At its core, AI aims to enable systems to exhibit cognitive functions such as:
#
# *   **Learning:** Acquiring knowledge and skills from data or experience.
# *   **Reasoning:** Applying logic and rules to reach conclusions.
# *   **Problem-solving:** Finding solutions to complex challenges.
# *   **Perception:** Interpreting sensory information (like images or speech).
# *   **Understanding:** Processing and making sense of natural language.
# *   **Decision-making:** Choosing actions based on available information and goals.
#
# AI achieves this through the use of sophisticated algorithms, statistical models, and vast amounts of data, allowing systems to learn, adapt, and make decisions with varying degrees of autonomy.
#
# **Key distinctions often made within AI:**
#
# *   **Narrow AI (or Weak AI):** Most of the AI we encounter today. It's designed and trained for a specific task (e.g., facial recognition, voice assistants, recommendation engines, playing chess). It performs that task exceptionally well but lacks general intelligence.
# *   **General AI (or Strong AI):** A hypothetical form of AI that would possess human-like cognitive abilities across a wide range of tasks, capable of learning, understanding, and applying knowledge to any intellectual task that a human being can. This level of AI does not currently exist.
#
# In essence, AI is about making machines "smart" enough to perform tasks that, if done by a human, would be considered intelligent.
# --------------------------------------------------
# Prompt 5: How does photosynthesis work?
# Response: Photosynthesis is the incredible process by which **plants, algae, and some bacteria** convert light energy into chemical energy, creating their own food (sugars) and releasing oxygen as a byproduct. It's essentially the foundation of most life on Earth.
#
# Here's a breakdown of how it works:
#
# **The Overall Equation (Simplified):**
#
# $6CO_2$ (Carbon Dioxide) + $6H_2O$ (Water) + Light Energy $\rightarrow$ $C_6H_{12}O_6$ (Glucose/Sugar) + $6O_2$ (Oxygen)
#
# **Key Ingredients:**
#
# 1.  **Sunlight:** The energy source.
# 2.  **Carbon Dioxide ($CO_2$):** Absorbed from the atmosphere through tiny pores on leaves called **stomata**.
# 3.  **Water ($H_2O$):** Absorbed from the soil through the roots.
#
# **The Location:**
#
# Photosynthesis primarily takes place in specialized organelles within plant cells called **chloroplasts**. Chloroplasts contain a green pigment called **chlorophyll**, which is responsible for absorbing light energy.
#
# **The Two Main Stages of Photosynthesis:**
#
# Photosynthesis isn't one single reaction; it's a complex series of reactions divided into two main stages:
#
# ---
#
# ### 1. Light-Dependent Reactions (The "Photo" Part)
#
# *   **Where:** These reactions occur in the **thylakoid membranes** within the chloroplasts. Thylakoids are like flattened sacs stacked into structures called grana.
# *   **What happens:**
#     1.  **Light Absorption:** Chlorophyll and other pigments in the thylakoid membranes absorb light energy (primarily red and blue wavelengths, reflecting green light, which is why plants appear green).
#     2.  **Water Splitting (Photolysis):** The absorbed light energy is used to split water molecules ($H_2O$). This process releases:
#         *   **Oxygen ($O_2$):** Released into the atmosphere as a byproduct (this is the oxygen we breathe!).
#         *   **Electrons ($e^-$):** These energized electrons are crucial for the next steps.
#         *   **Hydrogen ions ($H^+$):** Also used in subsequent steps.
#     3.  **Energy Conversion:** The energized electrons move along an **electron transport chain** (similar to a tiny electrical circuit). As they move, their energy is used to generate two important energy-carrying molecules:
#         *   **ATP (Adenosine Triphosphate):** The primary energy currency of the cell, like a rechargeable battery.
#         *   **NADPH (Nicotinamide Adenine Dinucleotide Phosphate):** An electron carrier that carries high-energy electrons (and $H^+$ ions) to the next stage.
# *   **Purpose:** To convert light energy into chemical energy in the form of ATP and NADPH, which will power the second stage.
#
# ---
#
# ### 2. Light-Independent Reactions (The "Synthesis" Part) - Also known as the Calvin Cycle
#
# *   **Where:** These reactions occur in the **stroma**, the fluid-filled space surrounding the thylakoids within the chloroplast.
# *   **What happens:**
#     1.  **Carbon Fixation:** Carbon dioxide ($CO_2$) from the atmosphere enters the stroma. An enzyme called RuBisCO (ribulose-1,5-bisphosphate carboxylase/oxygenase) combines $CO_2$ with an existing five-carbon sugar called RuBP (ribulose-1,5-bisphosphate). This "fixes" the inorganic carbon into an organic molecule.
#     2.  **Reduction:** The newly formed unstable six-carbon compound quickly splits into two three-carbon compounds. ATP provides the energy, and NADPH provides the high-energy electrons (reducing power) to convert these three-carbon compounds into a different three-carbon sugar called **G3P (glyceraldehyde-3-phosphate)**.
#     3.  **Sugar Formation:** For every six $CO_2$ molecules that enter the cycle, two molecules of G3P are produced. One of these G3P molecules leaves the cycle to be used by the plant to synthesize **glucose ($C_6H_{12}O_6$)** and other organic compounds (like starch for storage, cellulose for structure, proteins, lipids).
#     4.  **Regeneration:** The remaining G3P molecules are rearranged and, using more ATP, regenerate the starting molecule RuBP, allowing the cycle to continue.
# *   **Purpose:** To use the chemical energy (ATP) and reducing power (NADPH) generated in the light-dependent reactions to convert atmospheric carbon dioxide into glucose and other organic molecules.
#
# ---
#
# **In Summary:**
#
# Photosynthesis is a two-step factory:
#
# *   **Step 1 (Light-Dependent):** Uses sunlight and water to create energy carriers (ATP and NADPH) and releases oxygen.
# *   **Step 2 (Light-Independent/Calvin Cycle):** Uses the energy carriers (ATP and NADPH) and carbon dioxide to build sugars (glucose).
#
# This entire process is fundamental to life on Earth, providing the food base for most ecosystems and replenishing the oxygen in our atmosphere.
# --------------------------------------------------

# %% [markdown]
# - `llm.batch(prompts)`: Sends all the input prompts to the model in one call. It returns a list of response objects, one per input. This is significantly more efficient than looping over `llm.invoke()` individually.
#
# Batch processing is more efficient than individual calls for:
#   - Reduces network latency and API overhead.
#   - Makes better use of model rate limits and throughput.
#   - Faster overall processing time.
#
# #### Asynchronous batch processing

# %%
# Async batch processing for better performance
async def async_batch_example():
    prompts = [
        "What is machine learning?",
        "Explain blockchain technology.",
        "How do vaccines work?"
    ]

    # Send the prompts concurrently using the async abatch method
    responses = await llm.abatch(prompts)

    # Display each result
    for prompt, response in zip(prompts, responses):
        print(f"Q: {prompt}")
        print(f"A: {response.content[:100]}...")
        print("-" * 30)

await async_batch_example()
# Out:
# Q: What is machine learning?
# A: Machine learning (ML) is a **subset of Artificial Intelligence (AI)** that enables systems to **lear...
# ------------------------------
# Q: Explain blockchain technology.
# A: Blockchain technology is a **decentralized, distributed, and immutable ledger system** that records ...
# ------------------------------
# Q: How do vaccines work?
# A: Vaccines work by **training your immune system to recognize and fight off specific diseases without ...
# ------------------------------

# %% [markdown]
# - `await llm.abatch(prompts)`: Performs batch processing asynchronously — meaning it doesn't block the execution thread.
# - Uses `async` and `await` to allow concurrent task execution (e.g., handling multiple users in a web app).
#
# Async batch processing allows for:
#   - Improves application responsiveness — other tasks can run while waiting for responses.
#   - Scales better under load — handles many requests without blocking.
#   - Maximizes resource usage (CPU, I/O, etc.) with non-blocking behavior.
